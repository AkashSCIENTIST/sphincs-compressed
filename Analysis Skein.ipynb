# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\akash\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("result-SKEIN.csv")

# %%
df.head(30)
# Out:
#     SK Size  PK Size  Key Gen Time  Sign Size   Sign Time  Verify Time  \
# 0        64       32      0.140723       9248    3.083435     0.011537
# 1        64       32      0.016991      15824    0.588815     0.019916
# 2        96       48      0.106327      19800   10.019717     0.017950
# 3        96       48      0.024932      34440    0.871546     0.030915
# 4       128       64      0.271111      34848    9.742208     0.021911
# 5       128       64      0.070324      48352    1.827955     0.033441
# 6        64       32      0.641112       6245  196.974474     0.106332
# 7        64       32      0.018614      14688    0.732114     0.023936
# 8        96       48      0.473555      13381  239.001666     0.156470
# 9        96       48      0.028428      32725    1.114995     0.035871
# 10      128       64      0.731211      25957  295.134192     0.123184
# 11      128       64      0.075308      46497    2.280282     0.035929
# 12       64       32      0.567775       5893  191.912430     0.100243
# 13       64       32      0.017534      13683    0.752899     0.021939
# 14       96       48      0.461537      12853  238.598246     0.153169
# 15       96       48      0.026928      31214    1.084166     0.034945
# 16      128       64      0.717689      25253  289.393073     0.116846
# 17      128       64      0.072393      44956    2.067418     0.033911
# 18       64       32      0.498545       5541  188.476986     0.081923
# 19       64       32      0.014957      12682    0.989906     0.019535
# 20       96       48      0.402064      12325  232.222291     0.133284
# 21       96       48      0.024406      29707    1.409491     0.030404
# 22      128       64      0.661672      24549  280.643509     0.111213
# 23      128       64      0.068327      43422    2.093273     0.033877
# 24       64       32      0.433092       5189  181.755256     0.071169
# 25       64       32      0.013279      11679    7.245579     0.019412
# 26       96       48      0.368314      11797  226.682839     0.122184
# 27       96       48      0.023449      28196    2.598718     0.028890
# 28      128       64      0.629076      23845  275.978637     0.103198
# 29      128       64      0.064501      41891    2.676461     0.032416
#
#                Name
# 0     SPHINCS+ 128S
# 1     SPHINCS+ 128F
# 2     SPHINCS+ 192S
# 3     SPHINCS+ 192F
# 4     SPHINCS+ 256S
# 5     SPHINCS+ 256F
# 6   SPHINCS+C1 128S
# 7   SPHINCS+C1 128F
# 8   SPHINCS+C1 192S
# 9   SPHINCS+C1 192F
# 10  SPHINCS+C1 256S
# 11  SPHINCS+C1 256F
# 12  SPHINCS+C2 128S
# 13  SPHINCS+C2 128F
# 14  SPHINCS+C2 192S
# 15  SPHINCS+C2 192F
# 16  SPHINCS+C2 256S
# 17  SPHINCS+C2 256F
# 18  SPHINCS+C3 128S
# 19  SPHINCS+C3 128F
# 20  SPHINCS+C3 192S
# 21  SPHINCS+C3 192F
# 22  SPHINCS+C3 256S
# 23  SPHINCS+C3 256F
# 24  SPHINCS+C4 128S
# 25  SPHINCS+C4 128F
# 26  SPHINCS+C4 192S
# 27  SPHINCS+C4 192F
# 28  SPHINCS+C4 256S
# 29  SPHINCS+C4 256F

# %%
df = df.round(3)

# %%
def plot_bar_multi_columns(data, x_col, y_cols, y_label, colormap='viridis'):
    """
    Create a bar plot for multiple columns in a Pandas DataFrame with a gap between groups.

    Parameters:
    - data: The DataFrame containing the data to be plotted.
    - x_col: The name of the column to be used as the X-axis.
    - y_cols: A list of column names to be used as Y-axes.
    """
    # Extract X and Y data from the DataFrame
    x_data = data[x_col]
    y_data = data[y_cols]

    # Number of bars (Y-axes)
    num_y_axes = len(y_cols)
    

    # Set up the figure and axis with a larger figsize
    fig, ax = plt.subplots(figsize=(18, 12))

    # Width of each group of bars
    group_width = 1
    bar_width = (group_width / num_y_axes)-0.2

    # Define color options for bars
    colors = ['b', 'y', 'm', 'g', 'r', 'c', 'k']

    # Loop through each Y-axis and create a bar for each
    for i in range(num_y_axes):
        x_positions = [x + i * bar_width for x in range(len(x_data))]
        y_values = y_data[y_cols[i]]
        color = colors[i % len(colors)]  # Cycle through colors

        ax.bar(x_positions, y_values, width=bar_width, label=y_cols[i], color=color)

        # Add annotations to the bars
        for x, y in zip(x_positions, y_values):
            if len(y_cols) > 1:
                ax.text((x + bar_width / 2), y, "   " + str(y), ha='center', va='bottom', rotation=90, fontsize=12, weight='bold')
            else:
                ax.text((x + bar_width / 2)-0.4, y, "   " + str(y), ha='center', va='bottom', rotation=90, fontsize=12, weight='bold')

    # Set the X-axis labels and legend
    ax.set_xticks([(x + (group_width / 2))-0.5 for x in range(len(x_data))])
    ax.set_xticklabels(x_data, rotation=90, va='top', fontsize=12)
    plt.yticks(rotation=90, fontsize=12) 
    ax.set_xlabel(x_col, rotation=180, fontsize=12)
    ax.set_ylabel(y_label, fontsize=12)
    ax.margins(y=0.3)
    legend = ax.legend(loc='upper left',  bbox_to_anchor=(0, 1), ncol=len(y_cols))
    

    for item in legend.get_texts():
        item.set_rotation(90)

# %%
plot_bar_multi_columns(df, 'Name', ["Key Gen Time"], "Keys Generation Time (in seconds)", 'hsv')

# %%
plot_bar_multi_columns(df, 'Name', ["SK Size","PK Size"], "Key Size (in bytes)")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Time"], "Signature Generation Time (in seconds)")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Size"], "Signature Size (in Bytes)")

# %%
plot_bar_multi_columns(df, 'Name', ["Verify Time"], "Signature Verification Time (in seconds)")

# %%
df2 = df.sort_values(by=['Sign Size'])

# %%
df2.head(30)
# Out:
#     SK Size  PK Size  Key Gen Time  Sign Size  Sign Time  Verify Time  \
# 24       64       32         0.433       5189    181.755        0.071
# 18       64       32         0.499       5541    188.477        0.082
# 12       64       32         0.568       5893    191.912        0.100
# 6        64       32         0.641       6245    196.974        0.106
# 0        64       32         0.141       9248      3.083        0.012
# 25       64       32         0.013      11679      7.246        0.019
# 26       96       48         0.368      11797    226.683        0.122
# 20       96       48         0.402      12325    232.222        0.133
# 19       64       32         0.015      12682      0.990        0.020
# 14       96       48         0.462      12853    238.598        0.153
# 8        96       48         0.474      13381    239.002        0.156
# 13       64       32         0.018      13683      0.753        0.022
# 7        64       32         0.019      14688      0.732        0.024
# 1        64       32         0.017      15824      0.589        0.020
# 2        96       48         0.106      19800     10.020        0.018
# 28      128       64         0.629      23845    275.979        0.103
# 22      128       64         0.662      24549    280.644        0.111
# 16      128       64         0.718      25253    289.393        0.117
# 10      128       64         0.731      25957    295.134        0.123
# 27       96       48         0.023      28196      2.599        0.029
# 21       96       48         0.024      29707      1.409        0.030
# 15       96       48         0.027      31214      1.084        0.035
# 9        96       48         0.028      32725      1.115        0.036
# 3        96       48         0.025      34440      0.872        0.031
# 4       128       64         0.271      34848      9.742        0.022
# 29      128       64         0.065      41891      2.676        0.032
# 23      128       64         0.068      43422      2.093        0.034
# 17      128       64         0.072      44956      2.067        0.034
# 11      128       64         0.075      46497      2.280        0.036
# 5       128       64         0.070      48352      1.828        0.033
#
#                Name
# 24  SPHINCS+C4 128S
# 18  SPHINCS+C3 128S
# 12  SPHINCS+C2 128S
# 6   SPHINCS+C1 128S
# 0     SPHINCS+ 128S
# 25  SPHINCS+C4 128F
# 26  SPHINCS+C4 192S
# 20  SPHINCS+C3 192S
# 19  SPHINCS+C3 128F
# 14  SPHINCS+C2 192S
# 8   SPHINCS+C1 192S
# 13  SPHINCS+C2 128F
# 7   SPHINCS+C1 128F
# 1     SPHINCS+ 128F
# 2     SPHINCS+ 192S
# 28  SPHINCS+C4 256S
# 22  SPHINCS+C3 256S
# 16  SPHINCS+C2 256S
# 10  SPHINCS+C1 256S
# 27  SPHINCS+C4 192F
# 21  SPHINCS+C3 192F
# 15  SPHINCS+C2 192F
# 9   SPHINCS+C1 192F
# 3     SPHINCS+ 192F
# 4     SPHINCS+ 256S
# 29  SPHINCS+C4 256F
# 23  SPHINCS+C3 256F
# 17  SPHINCS+C2 256F
# 11  SPHINCS+C1 256F
# 5     SPHINCS+ 256F

# %%
plot_bar_multi_columns(
    df2, 'Name', ["Key Gen Time"], "Keys Generation Time", 'hsv')

# %%
plot_bar_multi_columns(df2, 'Name', ["SK Size","PK Size"], "Key Size")

# %%
plot_bar_multi_columns(df2, 'Name', ["Sign Time"], "Signature Generation Time")

# %%
plot_bar_multi_columns(df2, 'Name', ["Sign Size"], "Signature Size")

# %%
plot_bar_multi_columns(df2, 'Name', ["Verify Time"], "Verification Time")
