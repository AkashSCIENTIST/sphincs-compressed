# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\akash\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Declaring Global Parameters

# %%
a = 15 # FORS Tree Height
# k = 10 # FORS Tree Number
val_arr = []

# %%
parameters = {
    "128S" : {
        "n":16,
        "h":66,
        "d":11,
        "k":9,
        "w":128,
        "a":13
    },
    "128F" : {
        "n":16,
        "h":63,
        "d":21,
        "k":19,
        "w":16,
        "a":9
    },
    "192S" : {
        "n":24,
        "h":63,
        "d":11,
        "k":13,
        "w":128,
        "a":15
    },
    "192F" : {
        "n":24,
        "h":63,
        "d":21,
        "k":30,
        "w":16,
        "a":9
    },
    "256S" : {
        "n":32,
        "h":66,
        "d":11,
        "k":19,
        "w":64,
        "a":14
    },
    "256F" : {
        "n":32,
        "h":64,
        "d":16,
        "k":34,
        "w":16,
        "a":10
    },
}

m = b"No one knows the reason for all this, but it is probably quantum. - Pyramids, Terry Pratchett (1989)"

# %% [markdown]
# # SPHINCS+

# %%
from package.sphincs import Sphincs
from package.sphincsc import SphincsC

# %%
def SphincsUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = Sphincs()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_hash_fun(3)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except:
        
        print(name + " Failed")
    
    print("-"*50, "\n")

    return di

# %%
def SphincsCUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = SphincsC()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_cf(cf)
    sphincsc.set_hash_fun(3)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except Exception as e:
        
        print(name + " Failed")
        print(e)
    
    print("-"*50, "\n")

    return di

# %% [markdown]
# ## SPHINCS+128S

# %%
models = ["SPHINCS+", "SPHINCS+C1", "SPHINCS+C2", "SPHINCS+C3", "SPHINCS+C4"]
parameter_names = list(parameters.keys())

for cf, name in enumerate(models):
    if cf == 0:
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsUtil(**param, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
            print("-"*50, "\n")
    else:
        if name.endswith("F"):
            continue
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsCUtil(**param, cf=cf, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
# Out:
# SPHINCS+ 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.18102478981018066
# Time Taken to Sign 3.768603801727295
# Signature Size 9248 bytes
# Time Taken to Verify 0.012967586517333984
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.019968032836914062
# Time Taken to Sign 0.9319336414337158
# Signature Size 15824 bytes
# Time Taken to Verify 0.10956621170043945
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.49523329734802246
# Time Taken to Sign 12.129140138626099
# Signature Size 19800 bytes
# Time Taken to Verify 0.019946575164794922
# Is signature correct ?  False
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.02896857261657715
# Time Taken to Sign 0.9321634769439697
# Signature Size 34440 bytes
# Time Taken to Verify 0.03387641906738281
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.29482102394104004
# Time Taken to Sign 9.937060832977295
# Signature Size 34848 bytes
# Time Taken to Verify 0.023934364318847656
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.07392644882202148
# Time Taken to Sign 1.9426589012145996
# Signature Size 48352 bytes
# Time Taken to Verify 0.03554248809814453
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+C1 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.6917963027954102
# Time Taken to Sign 199.67185926437378
# Signature Size 6245 bytes
# Time Taken to Verify 0.11281681060791016
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.02023005485534668
# Time Taken to Sign 0.6913442611694336
# Signature Size 14685 bytes
# Time Taken to Verify 0.026690959930419922
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.5071225166320801
# Time Taken to Sign 245.22271132469177
# Signature Size 13381 bytes
# Time Taken to Verify 0.17270445823669434
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C1 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.029952049255371094
# Time Taken to Sign 1.0803327560424805
# Signature Size 32719 bytes
# Time Taken to Verify 0.03805232048034668
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.784740686416626
# Time Taken to Sign 294.52001452445984
# Signature Size 25957 bytes
# Time Taken to Verify 0.13112783432006836
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.08219003677368164
# Time Taken to Sign 2.165996789932251
# Signature Size 46488 bytes
# Time Taken to Verify 0.03937196731567383
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.6175951957702637
# Time Taken to Sign 194.37161827087402
# Signature Size 5893 bytes
# Time Taken to Verify 0.1003563404083252
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.0199429988861084
# Time Taken to Sign 0.7269032001495361
# Signature Size 13681 bytes
# Time Taken to Verify 0.02297210693359375
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.4642505645751953
# Time Taken to Sign 241.00197291374207
# Signature Size 12853 bytes
# Time Taken to Verify 0.1604628562927246
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C2 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.02840280532836914
# Time Taken to Sign 1.163994550704956
# Signature Size 31215 bytes
# Time Taken to Verify 0.034871578216552734
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.7425165176391602
# Time Taken to Sign 289.5042779445648
# Signature Size 25253 bytes
# Time Taken to Verify 0.1232762336730957
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.08038496971130371
# Time Taken to Sign 2.2176756858825684
# Signature Size 44957 bytes
# Time Taken to Verify 0.03593873977661133
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5460805892944336
# Time Taken to Sign 191.52107286453247
# Signature Size 5541 bytes
# Time Taken to Verify 0.09065794944763184
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.016954660415649414
# Time Taken to Sign 1.129796028137207
# Signature Size 12678 bytes
# Time Taken to Verify 0.02290797233581543
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.49770116806030273
# Time Taken to Sign 240.3054006099701
# Signature Size 12325 bytes
# Time Taken to Verify 0.1466047763824463
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C3 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.0278933048248291
# Time Taken to Sign 1.3503620624542236
# Signature Size 29702 bytes
# Time Taken to Verify 0.03393959999084473
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.7140886783599854
# Time Taken to Sign 284.61049914360046
# Signature Size 24549 bytes
# Time Taken to Verify 0.11665582656860352
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.07311701774597168
# Time Taken to Sign 2.206482410430908
# Signature Size 43420 bytes
# Time Taken to Verify 0.03587174415588379
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.47112011909484863
# Time Taken to Sign 184.37194061279297
# Signature Size 5189 bytes
# Time Taken to Verify 0.08879661560058594
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.01592397689819336
# Time Taken to Sign 10.015933275222778
# Signature Size 11681 bytes
# Time Taken to Verify 0.018455028533935547
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.39585280418395996
# Time Taken to Sign 231.24982833862305
# Signature Size 11797 bytes
# Time Taken to Verify 0.13104248046875
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C4 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.02490091323852539
# Time Taken to Sign 2.5460939407348633
# Signature Size 28196 bytes
# Time Taken to Verify 0.03191256523132324
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6694326400756836
# Time Taken to Sign 279.84446716308594
# Signature Size 23845 bytes
# Time Taken to Verify 0.11327552795410156
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06829667091369629
# Time Taken to Sign 2.76485538482666
# Signature Size 41890 bytes
# Time Taken to Verify 0.033873796463012695
# Is signature correct ?  True
# --------------------------------------------------

# %%
df = pd.DataFrame(val_arr)

# %%
df.to_csv("result-SHA1024.csv", encoding='utf-8', index=False)

# %%
df.head(len(val_arr))
# Out:
#     SK Size  PK Size  Key Gen Time  Sign Size   Sign Time  Verify Time  \
# 0        64       32      0.181025       9248    3.768604     0.012968
# 1        64       32      0.019968      15824    0.931934     0.109566
# 2        96       48      0.495233      19800   12.129140     0.019947
# 3        96       48      0.028969      34440    0.932163     0.033876
# 4       128       64      0.294821      34848    9.937061     0.023934
# 5       128       64      0.073926      48352    1.942659     0.035542
# 6        64       32      0.691796       6245  199.671859     0.112817
# 7        64       32      0.020230      14685    0.691344     0.026691
# 8        96       48      0.507123      13381  245.222711     0.172704
# 9        96       48      0.029952      32719    1.080333     0.038052
# 10      128       64      0.784741      25957  294.520015     0.131128
# 11      128       64      0.082190      46488    2.165997     0.039372
# 12       64       32      0.617595       5893  194.371618     0.100356
# 13       64       32      0.019943      13681    0.726903     0.022972
# 14       96       48      0.464251      12853  241.001973     0.160463
# 15       96       48      0.028403      31215    1.163995     0.034872
# 16      128       64      0.742517      25253  289.504278     0.123276
# 17      128       64      0.080385      44957    2.217676     0.035939
# 18       64       32      0.546081       5541  191.521073     0.090658
# 19       64       32      0.016955      12678    1.129796     0.022908
# 20       96       48      0.497701      12325  240.305401     0.146605
# 21       96       48      0.027893      29702    1.350362     0.033940
# 22      128       64      0.714089      24549  284.610499     0.116656
# 23      128       64      0.073117      43420    2.206482     0.035872
# 24       64       32      0.471120       5189  184.371941     0.088797
# 25       64       32      0.015924      11681   10.015933     0.018455
# 26       96       48      0.395853      11797  231.249828     0.131042
# 27       96       48      0.024901      28196    2.546094     0.031913
# 28      128       64      0.669433      23845  279.844467     0.113276
# 29      128       64      0.068297      41890    2.764855     0.033874
#
#                Name
# 0     SPHINCS+ 128S
# 1     SPHINCS+ 128F
# 2     SPHINCS+ 192S
# 3     SPHINCS+ 192F
# 4     SPHINCS+ 256S
# 5     SPHINCS+ 256F
# 6   SPHINCS+C1 128S
# 7   SPHINCS+C1 128F
# 8   SPHINCS+C1 192S
# 9   SPHINCS+C1 192F
# 10  SPHINCS+C1 256S
# 11  SPHINCS+C1 256F
# 12  SPHINCS+C2 128S
# 13  SPHINCS+C2 128F
# 14  SPHINCS+C2 192S
# 15  SPHINCS+C2 192F
# 16  SPHINCS+C2 256S
# 17  SPHINCS+C2 256F
# 18  SPHINCS+C3 128S
# 19  SPHINCS+C3 128F
# 20  SPHINCS+C3 192S
# 21  SPHINCS+C3 192F
# 22  SPHINCS+C3 256S
# 23  SPHINCS+C3 256F
# 24  SPHINCS+C4 128S
# 25  SPHINCS+C4 128F
# 26  SPHINCS+C4 192S
# 27  SPHINCS+C4 192F
# 28  SPHINCS+C4 256S
# 29  SPHINCS+C4 256F

# %%
df = df.round(3)

# %%
def plot_bar_multi_columns(data, x_col, y_cols, y_label, colormap='viridis'):
    """
    Create a bar plot for multiple columns in a Pandas DataFrame with a gap between groups.

    Parameters:
    - data: The DataFrame containing the data to be plotted.
    - x_col: The name of the column to be used as the X-axis.
    - y_cols: A list of column names to be used as Y-axes.
    """
    # Extract X and Y data from the DataFrame
    x_data = data[x_col]
    y_data = data[y_cols]

    # Number of bars (Y-axes)
    num_y_axes = len(y_cols)

    # Set up the figure and axis with a larger figsize
    fig, ax = plt.subplots(figsize=(16, 10))

    # Width of each group of bars
    group_width = 1
    bar_width = (group_width / num_y_axes)-0.2

    # Define color options for bars
    colors = ['g', 'y', 'm', 'b', 'r', 'c', 'k']

    # Loop through each Y-axis and create a bar for each
    for i in range(num_y_axes):
        x_positions = [x + i * bar_width for x in range(len(x_data))]
        y_values = y_data[y_cols[i]]
        color = colors[i % len(colors)]  # Cycle through colors

        ax.bar(x_positions, y_values, width=bar_width, label=y_cols[i], color=color)

        # Add annotations to the bars
        for x, y in zip(x_positions, y_values):
            ax.text((x + bar_width / 2)-0.4, y, str(y), ha='center', va='bottom')

    # Set the X-axis labels and legend
    ax.set_xticks([(x + (group_width / 2))-0.5 for x in range(len(x_data))])
    ax.set_xticklabels(x_data, rotation=90, va='top')
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_label)
    ax.legend()

# %%
plot_bar_multi_columns(df, 'Name', ["Key Gen Time"], "Keys Generation Time (in seconds)", 'hsv')

# %%
plot_bar_multi_columns(df, 'Name', ["SK Size","PK Size"], "Key Size (in bytes)")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Time"], "Signature Generation Time (in seconds)")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Size"], "Signature Size (in bytes)")

# %%
plot_bar_multi_columns(df, 'Name', ["Verify Time"], "Verification Time (in seconds)")

# %%
df2 = df.sort_values(by=['Sign Size'])

# %%
plot_bar_multi_columns(df2, 'Name', ["Key Gen Time"], "Keys Generation Time (in seconds)", 'hsv')

# %%
plot_bar_multi_columns(df2, 'Name', ["SK Size","PK Size"], "Key Size (in bytes)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Sign Time"], "Signature Generation Time (in seconds)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Sign Size"], "Signature Size (in bytes)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Verify Time"], "Verification Time (in seconds)")
