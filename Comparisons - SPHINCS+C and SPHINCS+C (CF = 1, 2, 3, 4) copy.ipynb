# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Declaring Global Parameters

# %%
a = 15 # FORS Tree Height
# k = 10 # FORS Tree Number
val_arr = []

# %%
parameters = {
    "128S" : {
        "n":16,
        "h":66,
        "d":11,
        "k":9,
        "w":128,
        "a":13
    },
    "128F" : {
        "n":16,
        "h":63,
        "d":21,
        "k":19,
        "w":16,
        "a":9
    },
    "192S" : {
        "n":24,
        "h":63,
        "d":11,
        "k":13,
        "w":128,
        "a":15
    },
    "192F" : {
        "n":24,
        "h":63,
        "d":21,
        "k":30,
        "w":16,
        "a":9
    },
    "256S" : {
        "n":32,
        "h":66,
        "d":11,
        "k":19,
        "w":64,
        "a":14
    },
    "256F" : {
        "n":32,
        "h":64,
        "d":16,
        "k":34,
        "w":16,
        "a":10
    },
}

m = b"No one knows the reason for all this, but it is probably quantum. - Pyramids, Terry Pratchett (1989)"

# %% [markdown]
# # SPHINCS+

# %%
from package.sphincs import Sphincs
from package.sphincsc import SphincsC

# %%
def SphincsUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = Sphincs()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except:
        
        print(name + " Failed")
    
    print("-"*50, "\n")

    return di

# %%
def SphincsCUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = SphincsC()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_cf(cf)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except Exception as e:
        
        print(name + " Failed")
        print(e)
    
    print("-"*50, "\n")

    return di

# %% [markdown]
# ## SPHINCS+128S

# %%
models = ["SPHINCS+", "SPHINCS+C1", "SPHINCS+C2", "SPHINCS+C3", "SPHINCS+C4"]
parameter_names = list(parameters.keys())

for cf, name in enumerate(models):
    if cf == 0:
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsUtil(**param, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
            print("-"*50, "\n")
    else:
        if name.endswith("F"):
            continue
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsCUtil(**param, cf=cf, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
# Out:
# SPHINCS+ 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.13550996780395508
# Time Taken to Sign 2.920398235321045
# Signature Size 9248 bytes
# Time Taken to Verify 0.011500358581542969
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.01598954200744629
# Time Taken to Sign 0.5408780574798584
# Signature Size 15824 bytes
# Time Taken to Verify 0.021745681762695312
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.09734892845153809
# Time Taken to Sign 9.636476755142212
# Signature Size 19800 bytes
# Time Taken to Verify 0.015956878662109375
# Is signature correct ?  False
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.023936033248901367
# Time Taken to Sign 0.8298864364624023
# Signature Size 34440 bytes
# Time Taken to Verify 0.02995467185974121
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.2510364055633545
# Time Taken to Sign 9.14682936668396
# Signature Size 34848 bytes
# Time Taken to Verify 0.019946813583374023
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06087493896484375
# Time Taken to Sign 1.7150588035583496
# Signature Size 48352 bytes
# Time Taken to Verify 0.02991771697998047
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+C1 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5739691257476807
# Time Taken to Sign 193.07007026672363
# Signature Size 6245 bytes
# Time Taken to Verify 0.09204888343811035
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.017372846603393555
# Time Taken to Sign 0.6749372482299805
# Signature Size 14689 bytes
# Time Taken to Verify 0.021907806396484375
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.41287755966186523
# Time Taken to Sign 238.75411367416382
# Signature Size 13381 bytes
# Time Taken to Verify 0.14429593086242676
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C1 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.026752233505249023
# Time Taken to Sign 0.9812304973602295
# Signature Size 32719 bytes
# Time Taken to Verify 0.033422231674194336
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6703207492828369
# Time Taken to Sign 290.82101798057556
# Signature Size 25957 bytes
# Time Taken to Verify 0.10832524299621582
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06849431991577148
# Time Taken to Sign 1.9952268600463867
# Signature Size 46491 bytes
# Time Taken to Verify 0.03091716766357422
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5144832134246826
# Time Taken to Sign 190.04186129570007
# Signature Size 5893 bytes
# Time Taken to Verify 0.08378434181213379
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.014960050582885742
# Time Taken to Sign 0.7277281284332275
# Signature Size 13685 bytes
# Time Taken to Verify 0.02293705940246582
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.40442323684692383
# Time Taken to Sign 240.4249448776245
# Signature Size 12853 bytes
# Time Taken to Verify 0.13016533851623535
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C2 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.027957439422607422
# Time Taken to Sign 1.0555555820465088
# Signature Size 31211 bytes
# Time Taken to Verify 0.030919313430786133
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6542611122131348
# Time Taken to Sign 294.6824266910553
# Signature Size 25253 bytes
# Time Taken to Verify 0.11420106887817383
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06554365158081055
# Time Taken to Sign 2.0658929347991943
# Signature Size 44954 bytes
# Time Taken to Verify 0.03388023376464844
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5012757778167725
# Time Taken to Sign 211.73225116729736
# Signature Size 5541 bytes
# Time Taken to Verify 0.08210110664367676
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.01619100570678711
# Time Taken to Sign 1.0344374179840088
# Signature Size 12681 bytes
# Time Taken to Verify 0.01795053482055664
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.36507153511047363
# Time Taken to Sign 260.1747500896454
# Signature Size 12325 bytes
# Time Taken to Verify 0.13131999969482422
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C3 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.024445533752441406
# Time Taken to Sign 1.5073363780975342
# Signature Size 29706 bytes
# Time Taken to Verify 0.03591442108154297
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.7211675643920898
# Time Taken to Sign 321.397123336792
# Signature Size 24549 bytes
# Time Taken to Verify 0.10120630264282227
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06409788131713867
# Time Taken to Sign 2.184636116027832
# Signature Size 43424 bytes
# Time Taken to Verify 0.03344225883483887
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.4086172580718994
# Time Taken to Sign 185.31030869483948
# Signature Size 5189 bytes
# Time Taken to Verify 0.06691598892211914
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.012946128845214844
# Time Taken to Sign 9.770690441131592
# Signature Size 11680 bytes
# Time Taken to Verify 0.018700361251831055
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.39581775665283203
# Time Taken to Sign 234.32768511772156
# Signature Size 11797 bytes
# Time Taken to Verify 0.11565184593200684
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C4 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.021727561950683594
# Time Taken to Sign 2.294578790664673
# Signature Size 28197 bytes
# Time Taken to Verify 0.03139185905456543
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.5963046550750732
# Time Taken to Sign 285.04711270332336
# Signature Size 23845 bytes
# Time Taken to Verify 0.0975790023803711
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06160330772399902
# Time Taken to Sign 2.947953701019287
# Signature Size 41892 bytes
# Time Taken to Verify 0.028430938720703125
# Is signature correct ?  True
# --------------------------------------------------

# %%
df = pd.DataFrame(val_arr)

# %%
df.to_csv("result.csv", encoding='utf-8', index=False)

# %%
df.head(len(val_arr))
# Out:
#     SK Size  PK Size  Key Gen Time  Sign Size   Sign Time  Verify Time  \
# 0        64       32      0.135510       9248    2.920398     0.011500
# 1        64       32      0.015990      15824    0.540878     0.021746
# 2        96       48      0.097349      19800    9.636477     0.015957
# 3        96       48      0.023936      34440    0.829886     0.029955
# 4       128       64      0.251036      34848    9.146829     0.019947
# 5       128       64      0.060875      48352    1.715059     0.029918
# 6        64       32      0.573969       6245  193.070070     0.092049
# 7        64       32      0.017373      14689    0.674937     0.021908
# 8        96       48      0.412878      13381  238.754114     0.144296
# 9        96       48      0.026752      32719    0.981230     0.033422
# 10      128       64      0.670321      25957  290.821018     0.108325
# 11      128       64      0.068494      46491    1.995227     0.030917
# 12       64       32      0.514483       5893  190.041861     0.083784
# 13       64       32      0.014960      13685    0.727728     0.022937
# 14       96       48      0.404423      12853  240.424945     0.130165
# 15       96       48      0.027957      31211    1.055556     0.030919
# 16      128       64      0.654261      25253  294.682427     0.114201
# 17      128       64      0.065544      44954    2.065893     0.033880
# 18       64       32      0.501276       5541  211.732251     0.082101
# 19       64       32      0.016191      12681    1.034437     0.017951
# 20       96       48      0.365072      12325  260.174750     0.131320
# 21       96       48      0.024446      29706    1.507336     0.035914
# 22      128       64      0.721168      24549  321.397123     0.101206
# 23      128       64      0.064098      43424    2.184636     0.033442
# 24       64       32      0.408617       5189  185.310309     0.066916
# 25       64       32      0.012946      11680    9.770690     0.018700
# 26       96       48      0.395818      11797  234.327685     0.115652
# 27       96       48      0.021728      28197    2.294579     0.031392
# 28      128       64      0.596305      23845  285.047113     0.097579
# 29      128       64      0.061603      41892    2.947954     0.028431
#
#                Name
# 0     SPHINCS+ 128S
# 1     SPHINCS+ 128F
# 2     SPHINCS+ 192S
# 3     SPHINCS+ 192F
# 4     SPHINCS+ 256S
# 5     SPHINCS+ 256F
# 6   SPHINCS+C1 128S
# 7   SPHINCS+C1 128F
# 8   SPHINCS+C1 192S
# 9   SPHINCS+C1 192F
# 10  SPHINCS+C1 256S
# 11  SPHINCS+C1 256F
# 12  SPHINCS+C2 128S
# 13  SPHINCS+C2 128F
# 14  SPHINCS+C2 192S
# 15  SPHINCS+C2 192F
# 16  SPHINCS+C2 256S
# 17  SPHINCS+C2 256F
# 18  SPHINCS+C3 128S
# 19  SPHINCS+C3 128F
# 20  SPHINCS+C3 192S
# 21  SPHINCS+C3 192F
# 22  SPHINCS+C3 256S
# 23  SPHINCS+C3 256F
# 24  SPHINCS+C4 128S
# 25  SPHINCS+C4 128F
# 26  SPHINCS+C4 192S
# 27  SPHINCS+C4 192F
# 28  SPHINCS+C4 256S
# 29  SPHINCS+C4 256F

# %%
df = df.round(3)

# %%
def plot_bar_multi_columns(data, x_col, y_cols, y_label, colormap='viridis'):
    """
    Create a bar plot for multiple columns in a Pandas DataFrame with a gap between groups.

    Parameters:
    - data: The DataFrame containing the data to be plotted.
    - x_col: The name of the column to be used as the X-axis.
    - y_cols: A list of column names to be used as Y-axes.
    """
    # Extract X and Y data from the DataFrame
    x_data = data[x_col]
    y_data = data[y_cols]

    # Number of bars (Y-axes)
    num_y_axes = len(y_cols)

    # Set up the figure and axis with a larger figsize
    fig, ax = plt.subplots(figsize=(16, 10))

    # Width of each group of bars
    group_width = 1
    bar_width = (group_width / num_y_axes)-0.2

    # Define color options for bars
    colors = ['g', 'y', 'm', 'b', 'r', 'c', 'k']

    # Loop through each Y-axis and create a bar for each
    for i in range(num_y_axes):
        x_positions = [x + i * bar_width for x in range(len(x_data))]
        y_values = y_data[y_cols[i]]
        color = colors[i % len(colors)]  # Cycle through colors

        ax.bar(x_positions, y_values, width=bar_width, label=y_cols[i], color=color)

        # Add annotations to the bars
        for x, y in zip(x_positions, y_values):
            ax.text((x + bar_width / 2)-0.4, y, str(y), ha='center', va='bottom')

    # Set the X-axis labels and legend
    ax.set_xticks([(x + (group_width / 2))-0.5 for x in range(len(x_data))])
    ax.set_xticklabels(x_data, rotation=90, va='top')
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_label)
    ax.legend()

# %%
plot_bar_multi_columns(df, 'Name', ["Key Gen Time"], "Keys Generation Time", 'hsv')

# %%
plot_bar_multi_columns(df, 'Name', ["SK Size","PK Size"], "Key Size")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Time"], "Signature Generation Time")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Size"], "Signature Size")

# %%
plot_bar_multi_columns(df, 'Name', ["Verify Time"], "Verification Time")

# %%
df
