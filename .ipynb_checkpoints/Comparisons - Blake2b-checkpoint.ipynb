# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\akash\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Declaring Global Parameters

# %%
a = 15 # FORS Tree Height
# k = 10 # FORS Tree Number
val_arr = []

# %%
parameters = {
    "128S" : {
        "n":16,
        "h":66,
        "d":11,
        "k":9,
        "w":128,
        "a":13
    },
    "128F" : {
        "n":16,
        "h":63,
        "d":21,
        "k":19,
        "w":16,
        "a":9
    },
    "192S" : {
        "n":24,
        "h":63,
        "d":11,
        "k":13,
        "w":128,
        "a":15
    },
    "192F" : {
        "n":24,
        "h":63,
        "d":21,
        "k":30,
        "w":16,
        "a":9
    },
    "256S" : {
        "n":32,
        "h":66,
        "d":11,
        "k":19,
        "w":64,
        "a":14
    },
    "256F" : {
        "n":32,
        "h":64,
        "d":16,
        "k":34,
        "w":16,
        "a":10
    },
}

m = b"No one knows the reason for all this, but it is probably quantum. - Pyramids, Terry Pratchett (1989)"

# %% [markdown]
# # SPHINCS+

# %%
from package.sphincs import Sphincs
from package.sphincsc import SphincsC

# %%
def SphincsUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = Sphincs()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_hash_fun(1)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except:
        
        print(name + " Failed")
    
    print("-"*50, "\n")

    return di

# %%
def SphincsCUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = SphincsC()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_cf(cf)
    sphincsc.set_hash_fun(1)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except Exception as e:
        
        print(name + " Failed")
        print(e)
    
    print("-"*50, "\n")

    return di

# %% [markdown]
# ## SPHINCS+128S

# %%
models = ["SPHINCS+", "SPHINCS+C1", "SPHINCS+C2", "SPHINCS+C3", "SPHINCS+C4"]
parameter_names = list(parameters.keys())

for cf, name in enumerate(models):
    if cf == 0:
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsUtil(**param, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
            print("-"*50, "\n")
    else:
        if name.endswith("F"):
            continue
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsCUtil(**param, cf=cf, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
# Out:
# SPHINCS+ 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.2309408187866211
# Time Taken to Sign 3.4401423931121826
# Signature Size 9248 bytes
# Time Taken to Verify 0.01097249984741211
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.018948078155517578
# Time Taken to Sign 0.6790730953216553
# Signature Size 15824 bytes
# Time Taken to Verify 0.02091383934020996
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.10452747344970703
# Time Taken to Sign 11.836703538894653
# Signature Size 19800 bytes
# Time Taken to Verify 0.015977144241333008
# Is signature correct ?  False
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.02596426010131836
# Time Taken to Sign 0.9694092273712158
# Signature Size 34440 bytes
# Time Taken to Verify 0.030917882919311523
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.27158665657043457
# Time Taken to Sign 10.851674795150757
# Signature Size 34848 bytes
# Time Taken to Verify 0.020949602127075195
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06842303276062012
# Time Taken to Sign 1.9692785739898682
# Signature Size 48352 bytes
# Time Taken to Verify 0.02942681312561035
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+C1 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.60369873046875
# Time Taken to Sign 238.29761672019958
# Signature Size 6245 bytes
# Time Taken to Verify 0.11087846755981445
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.02547764778137207
# Time Taken to Sign 0.7747070789337158
# Signature Size 14685 bytes
# Time Taken to Verify 0.02252364158630371
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.4741690158843994
# Time Taken to Sign 296.46629071235657
# Signature Size 13381 bytes
# Time Taken to Verify 0.1469581127166748
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C1 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.02895355224609375
# Time Taken to Sign 1.2461235523223877
# Signature Size 32723 bytes
# Time Taken to Verify 0.034454345703125
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.7471218109130859
# Time Taken to Sign 366.7894129753113
# Signature Size 25957 bytes
# Time Taken to Verify 0.11754202842712402
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.07897734642028809
# Time Taken to Sign 2.3828115463256836
# Signature Size 46492 bytes
# Time Taken to Verify 0.0354156494140625
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5430159568786621
# Time Taken to Sign 239.76472759246826
# Signature Size 5893 bytes
# Time Taken to Verify 0.0932321548461914
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.018950462341308594
# Time Taken to Sign 0.8015239238739014
# Signature Size 13684 bytes
# Time Taken to Verify 0.02593207359313965
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.4726417064666748
# Time Taken to Sign 289.1998221874237
# Signature Size 12853 bytes
# Time Taken to Verify 0.13817954063415527
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C2 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.027509689331054688
# Time Taken to Sign 1.2210240364074707
# Signature Size 31214 bytes
# Time Taken to Verify 0.03191351890563965
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.8310208320617676
# Time Taken to Sign 353.9859445095062
# Signature Size 25253 bytes
# Time Taken to Verify 0.10867166519165039
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.07288932800292969
# Time Taken to Sign 2.265597105026245
# Signature Size 44956 bytes
# Time Taken to Verify 0.03255891799926758
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.4852018356323242
# Time Taken to Sign 225.3800346851349
# Signature Size 5541 bytes
# Time Taken to Verify 0.07912564277648926
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.015924930572509766
# Time Taken to Sign 1.2262861728668213
# Signature Size 12683 bytes
# Time Taken to Verify 0.022904634475708008
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.4161531925201416
# Time Taken to Sign 285.1770691871643
# Signature Size 12325 bytes
# Time Taken to Verify 0.12676048278808594
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C3 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.025014400482177734
# Time Taken to Sign 1.5951054096221924
# Signature Size 29706 bytes
# Time Taken to Verify 0.03992438316345215
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6518769264221191
# Time Taken to Sign 348.3139443397522
# Signature Size 24549 bytes
# Time Taken to Verify 0.10536742210388184
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06878328323364258
# Time Taken to Sign 2.2465572357177734
# Signature Size 43420 bytes
# Time Taken to Verify 0.03191351890563965
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.4470531940460205
# Time Taken to Sign 220.7864797115326
# Signature Size 5189 bytes
# Time Taken to Verify 0.06881570816040039
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.012966632843017578
# Time Taken to Sign 9.025043964385986
# Signature Size 11678 bytes
# Time Taken to Verify 0.016952991485595703
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.3520236015319824
# Time Taken to Sign 221.39142847061157
# Signature Size 11797 bytes
# Time Taken to Verify 0.08976244926452637
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C4 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.017498493194580078
# Time Taken to Sign 3.165666341781616
# Signature Size 28195 bytes
# Time Taken to Verify 0.021940946578979492
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.4693262577056885
# Time Taken to Sign 262.6743152141571
# Signature Size 23845 bytes
# Time Taken to Verify 0.07730793952941895
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.050901174545288086
# Time Taken to Sign 2.696737766265869
# Signature Size 41891 bytes
# Time Taken to Verify 0.024593114852905273
# Is signature correct ?  True
# --------------------------------------------------

# %%
df = pd.DataFrame(val_arr)

# %%
df.to_csv("result-BLAKE.csv", encoding='utf-8', index=False)

# %%
df.head(len(val_arr))
# Out:
#     SK Size  PK Size  Key Gen Time  Sign Size  Sign Time  Verify Time  \
# 0        64       32         0.231       9248      3.440        0.011
# 1        64       32         0.019      15824      0.679        0.021
# 2        96       48         0.105      19800     11.837        0.016
# 3        96       48         0.026      34440      0.969        0.031
# 4       128       64         0.272      34848     10.852        0.021
# 5       128       64         0.068      48352      1.969        0.029
# 6        64       32         0.604       6245    238.298        0.111
# 7        64       32         0.025      14685      0.775        0.023
# 8        96       48         0.474      13381    296.466        0.147
# 9        96       48         0.029      32723      1.246        0.034
# 10      128       64         0.747      25957    366.789        0.118
# 11      128       64         0.079      46492      2.383        0.035
# 12       64       32         0.543       5893    239.765        0.093
# 13       64       32         0.019      13684      0.802        0.026
# 14       96       48         0.473      12853    289.200        0.138
# 15       96       48         0.028      31214      1.221        0.032
# 16      128       64         0.831      25253    353.986        0.109
# 17      128       64         0.073      44956      2.266        0.033
# 18       64       32         0.485       5541    225.380        0.079
# 19       64       32         0.016      12683      1.226        0.023
# 20       96       48         0.416      12325    285.177        0.127
# 21       96       48         0.025      29706      1.595        0.040
# 22      128       64         0.652      24549    348.314        0.105
# 23      128       64         0.069      43420      2.247        0.032
# 24       64       32         0.447       5189    220.786        0.069
# 25       64       32         0.013      11678      9.025        0.017
# 26       96       48         0.352      11797    221.391        0.090
# 27       96       48         0.017      28195      3.166        0.022
# 28      128       64         0.469      23845    262.674        0.077
# 29      128       64         0.051      41891      2.697        0.025
#
#                Name
# 0     SPHINCS+ 128S
# 1     SPHINCS+ 128F
# 2     SPHINCS+ 192S
# 3     SPHINCS+ 192F
# 4     SPHINCS+ 256S
# 5     SPHINCS+ 256F
# 6   SPHINCS+C1 128S
# 7   SPHINCS+C1 128F
# 8   SPHINCS+C1 192S
# 9   SPHINCS+C1 192F
# 10  SPHINCS+C1 256S
# 11  SPHINCS+C1 256F
# 12  SPHINCS+C2 128S
# 13  SPHINCS+C2 128F
# 14  SPHINCS+C2 192S
# 15  SPHINCS+C2 192F
# 16  SPHINCS+C2 256S
# 17  SPHINCS+C2 256F
# 18  SPHINCS+C3 128S
# 19  SPHINCS+C3 128F
# 20  SPHINCS+C3 192S
# 21  SPHINCS+C3 192F
# 22  SPHINCS+C3 256S
# 23  SPHINCS+C3 256F
# 24  SPHINCS+C4 128S
# 25  SPHINCS+C4 128F
# 26  SPHINCS+C4 192S
# 27  SPHINCS+C4 192F
# 28  SPHINCS+C4 256S
# 29  SPHINCS+C4 256F

# %%
df = df.round(3)

# %%
def plot_bar_multi_columns(data, x_col, y_cols, y_label, colormap='viridis'):
    """
    Create a bar plot for multiple columns in a Pandas DataFrame with a gap between groups.

    Parameters:
    - data: The DataFrame containing the data to be plotted.
    - x_col: The name of the column to be used as the X-axis.
    - y_cols: A list of column names to be used as Y-axes.
    """
    # Extract X and Y data from the DataFrame
    x_data = data[x_col]
    y_data = data[y_cols]

    # Number of bars (Y-axes)
    num_y_axes = len(y_cols)

    # Set up the figure and axis with a larger figsize
    fig, ax = plt.subplots(figsize=(16, 10))

    # Width of each group of bars
    group_width = 1
    bar_width = (group_width / num_y_axes)-0.2

    # Define color options for bars
    colors = ['g', 'y', 'm', 'b', 'r', 'c', 'k']

    # Loop through each Y-axis and create a bar for each
    for i in range(num_y_axes):
        x_positions = [x + i * bar_width for x in range(len(x_data))]
        y_values = y_data[y_cols[i]]
        color = colors[i % len(colors)]  # Cycle through colors

        ax.bar(x_positions, y_values, width=bar_width, label=y_cols[i], color=color)

        # Add annotations to the bars
        for x, y in zip(x_positions, y_values):
            ax.text((x + bar_width / 2)-0.4, y, str(y), ha='center', va='bottom')

    # Set the X-axis labels and legend
    ax.set_xticks([(x + (group_width / 2))-0.5 for x in range(len(x_data))])
    ax.set_xticklabels(x_data, rotation=90, va='top')
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_label)
    ax.legend()

# %%
plot_bar_multi_columns(df, 'Name', ["Key Gen Time"], "Keys Generation Time (in seconds)", 'hsv')

# %%
plot_bar_multi_columns(df, 'Name', ["SK Size","PK Size"], "Key Size (in bytes)")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Time"], "Signature Generation Time (in seconds)")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Size"], "Signature Size (in bytes)")

# %%
plot_bar_multi_columns(df, 'Name', ["Verify Time"], "Verification Time (in seconds)")

# %%
df2 = df.sort_values(by=['Sign Size'])

# %%
plot_bar_multi_columns(df2, 'Name', ["Key Gen Time"], "Keys Generation Time (in seconds)", 'hsv')

# %%
plot_bar_multi_columns(df2, 'Name', ["SK Size","PK Size"], "Key Size (in bytes)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Sign Time"], "Signature Generation Time (in seconds)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Sign Size"], "Signature Size (in bytes)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Verify Time"], "Verification Time (in seconds)")
