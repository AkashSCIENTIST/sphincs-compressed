# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Declaring Global Parameters

# %%
a = 15 # FORS Tree Height
# k = 10 # FORS Tree Number
val_arr = []

# %%
parameters = {
    "128S" : {
        "n":16,
        "h":66,
        "d":11,
        "k":9,
        "w":128,
        "a":13
    },
    "128F" : {
        "n":16,
        "h":63,
        "d":21,
        "k":19,
        "w":16,
        "a":9
    },
    "192S" : {
        "n":24,
        "h":63,
        "d":11,
        "k":13,
        "w":128,
        "a":15
    },
    "192F" : {
        "n":24,
        "h":63,
        "d":21,
        "k":30,
        "w":16,
        "a":9
    },
    "256S" : {
        "n":32,
        "h":66,
        "d":11,
        "k":19,
        "w":64,
        "a":14
    },
    "256F" : {
        "n":32,
        "h":64,
        "d":16,
        "k":34,
        "w":16,
        "a":10
    },
}

m = b"No one knows the reason for all this, but it is probably quantum. - Pyramids, Terry Pratchett (1989)"

# %% [markdown]
# # SPHINCS+

# %%
from package.sphincs import Sphincs
from package.sphincsc3 import SphincsC

# %%
def SphincsUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = Sphincs()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except:
        
        print(name + " Failed")
    
    print("-"*50, "\n")

    return di

# %%
def SphincsCUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = SphincsC()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_cf(cf)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except Exception as e:
        
        print(name + " Failed")
        print(e)
    
    print("-"*50, "\n")

    return di

# %% [markdown]
# ## SPHINCS+128S

# %%
models = ["SPHINCS+", "SPHINCS+C1", "SPHINCS+C2", "SPHINCS+C3", "SPHINCS+C4"]
parameter_names = list(parameters.keys())

for cf, name in enumerate(models):
    if cf == 0:
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsUtil(**param, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
            print("-"*50, "\n")
    else:
        if name.endswith("F"):
            continue
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsCUtil(**param, cf=cf, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
# Out:
# SPHINCS+ 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.2238316535949707
# Time Taken to Sign 4.994783878326416
# Signature Size 9248 bytes
# Time Taken to Verify 0.02439713478088379
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.029631614685058594
# Time Taken to Sign 0.8872520923614502
# Signature Size 15824 bytes
# Time Taken to Verify 0.035520076751708984
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.17456364631652832
# Time Taken to Sign 13.189588785171509
# Signature Size 19800 bytes
# Time Taken to Verify 0.02789473533630371
# Is signature correct ?  False
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.03841114044189453
# Time Taken to Sign 1.3159959316253662
# Signature Size 34440 bytes
# Time Taken to Verify 0.050887107849121094
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.4134840965270996
# Time Taken to Sign 12.427058219909668
# Signature Size 34848 bytes
# Time Taken to Verify 0.0354161262512207
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.10024809837341309
# Time Taken to Sign 2.7146592140197754
# Signature Size 48352 bytes
# Time Taken to Verify 0.052102088928222656
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+C1 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5879242420196533
# Time Taken to Sign 198.60720133781433
# Signature Size 6245 bytes
# Time Taken to Verify 0.026926755905151367
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.01715683937072754
# Time Taken to Sign 0.697352409362793
# Signature Size 14688 bytes
# Time Taken to Verify 0.020914316177368164
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.4190523624420166
# Time Taken to Sign 243.74012970924377
# Signature Size 13381 bytes
# Time Taken to Verify 0.06429696083068848
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C1 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.025046348571777344
# Time Taken to Sign 1.0062050819396973
# Signature Size 32720 bytes
# Time Taken to Verify 0.03194451332092285
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6515190601348877
# Time Taken to Sign 701.9442248344421
# Signature Size 25957 bytes
# Time Taken to Verify 0.0518646240234375
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.0691225528717041
# Time Taken to Sign 2.0796070098876953
# Signature Size 46493 bytes
# Time Taken to Verify 0.031914472579956055
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5214571952819824
# Time Taken to Sign 207.10296273231506
# Signature Size 5893 bytes
# Time Taken to Verify 0.04336285591125488
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.015956640243530273
# Time Taken to Sign 0.6335756778717041
# Signature Size 13681 bytes
# Time Taken to Verify 0.01955437660217285
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.39620399475097656

# %%
df = pd.DataFrame(val_arr)

# %%
df.to_csv("result3.csv", encoding='utf-8', index=False)

# %%
df.head(len(val_arr))

# %%
df = df.round(3)

# %%
def plot_bar_multi_columns(data, x_col, y_cols, y_label, colormap='viridis'):
    """
    Create a bar plot for multiple columns in a Pandas DataFrame with a gap between groups.

    Parameters:
    - data: The DataFrame containing the data to be plotted.
    - x_col: The name of the column to be used as the X-axis.
    - y_cols: A list of column names to be used as Y-axes.
    """
    # Extract X and Y data from the DataFrame
    x_data = data[x_col]
    y_data = data[y_cols]

    # Number of bars (Y-axes)
    num_y_axes = len(y_cols)

    # Set up the figure and axis with a larger figsize
    fig, ax = plt.subplots(figsize=(16, 10))

    # Width of each group of bars
    group_width = 1
    bar_width = (group_width / num_y_axes)-0.2

    # Define color options for bars
    colors = ['g', 'y', 'm', 'b', 'r', 'c', 'k']

    # Loop through each Y-axis and create a bar for each
    for i in range(num_y_axes):
        x_positions = [x + i * bar_width for x in range(len(x_data))]
        y_values = y_data[y_cols[i]]
        color = colors[i % len(colors)]  # Cycle through colors

        ax.bar(x_positions, y_values, width=bar_width, label=y_cols[i], color=color)

        # Add annotations to the bars
        for x, y in zip(x_positions, y_values):
            ax.text((x + bar_width / 2)-0.4, y, str(y), ha='center', va='bottom')

    # Set the X-axis labels and legend
    ax.set_xticks([(x + (group_width / 2))-0.5 for x in range(len(x_data))])
    ax.set_xticklabels(x_data, rotation=90, va='top')
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_label)
    ax.legend()

# %%
plot_bar_multi_columns(df, 'Name', ["Key Gen Time"], "Keys Generation Time", 'hsv')

# %%
plot_bar_multi_columns(df, 'Name', ["SK Size","PK Size"], "Key Size")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Time"], "Signature Generation Time")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Size"], "Signature Size")

# %%
plot_bar_multi_columns(df, 'Name', ["Verify Time"], "Verification Time")

# %%
df
