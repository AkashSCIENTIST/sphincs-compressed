# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\akash\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Declaring Global Parameters

# %%
a = 15 # FORS Tree Height
# k = 10 # FORS Tree Number
val_arr = []

# %%
parameters = {
    "128S" : {
        "n":16,
        "h":66,
        "d":11,
        "k":9,
        "w":128,
        "a":13
    },
    "128F" : {
        "n":16,
        "h":63,
        "d":21,
        "k":19,
        "w":16,
        "a":9
    },
    "192S" : {
        "n":24,
        "h":63,
        "d":11,
        "k":13,
        "w":128,
        "a":15
    },
    "192F" : {
        "n":24,
        "h":63,
        "d":21,
        "k":30,
        "w":16,
        "a":9
    },
    "256S" : {
        "n":32,
        "h":66,
        "d":11,
        "k":19,
        "w":64,
        "a":14
    },
    "256F" : {
        "n":32,
        "h":64,
        "d":16,
        "k":34,
        "w":16,
        "a":10
    },
}

m = b"No one knows the reason for all this, but it is probably quantum. - Pyramids, Terry Pratchett (1989)"

# %% [markdown]
# # SPHINCS+

# %%
from package.sphincs import Sphincs
from package.sphincsc import SphincsC

# %%
def SphincsUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = Sphincs()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_hash_fun(2)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except:
        
        print(name + " Failed")
    
    print("-"*50, "\n")

    return di

# %%
def SphincsCUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = SphincsC()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_cf(cf)
    sphincsc.set_hash_fun(2)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except Exception as e:
        
        print(name + " Failed")
        print(e)
    
    print("-"*50, "\n")

    return di

# %% [markdown]
# ## SPHINCS+128S

# %%
models = ["SPHINCS+", "SPHINCS+C1", "SPHINCS+C2", "SPHINCS+C3", "SPHINCS+C4"]
parameter_names = list(parameters.keys())

for cf, name in enumerate(models):
    if cf == 0:
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsUtil(**param, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
            print("-"*50, "\n")
    else:
        if name.endswith("F"):
            continue
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsCUtil(**param, cf=cf, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
# Out:
# SPHINCS+ 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.14072322845458984
# Time Taken to Sign 3.083434581756592
# Signature Size 9248 bytes
# Time Taken to Verify 0.011537313461303711
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.01699066162109375
# Time Taken to Sign 0.5888152122497559
# Signature Size 15824 bytes
# Time Taken to Verify 0.01991558074951172
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.10632681846618652
# Time Taken to Sign 10.01971697807312
# Signature Size 19800 bytes
# Time Taken to Verify 0.01795029640197754
# Is signature correct ?  False
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.024932146072387695
# Time Taken to Sign 0.8715457916259766
# Signature Size 34440 bytes
# Time Taken to Verify 0.030915260314941406
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.27111053466796875
# Time Taken to Sign 9.742208242416382
# Signature Size 34848 bytes
# Time Taken to Verify 0.021910667419433594
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.07032370567321777
# Time Taken to Sign 1.8279550075531006
# Signature Size 48352 bytes
# Time Taken to Verify 0.033440589904785156
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+C1 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.6411118507385254
# Time Taken to Sign 196.9744737148285
# Signature Size 6245 bytes
# Time Taken to Verify 0.10633158683776855
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.018613815307617188
# Time Taken to Sign 0.7321135997772217
# Signature Size 14688 bytes
# Time Taken to Verify 0.023936033248901367
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.473555326461792
# Time Taken to Sign 239.0016655921936
# Signature Size 13381 bytes
# Time Taken to Verify 0.15647006034851074
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C1 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.028427600860595703
# Time Taken to Sign 1.114994764328003
# Signature Size 32725 bytes
# Time Taken to Verify 0.035871267318725586
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.7312114238739014
# Time Taken to Sign 295.1341915130615
# Signature Size 25957 bytes
# Time Taken to Verify 0.1231842041015625
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.07530832290649414
# Time Taken to Sign 2.2802815437316895
# Signature Size 46497 bytes
# Time Taken to Verify 0.035929203033447266
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5677745342254639
# Time Taken to Sign 191.9124300479889
# Signature Size 5893 bytes
# Time Taken to Verify 0.10024309158325195
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.017534255981445312
# Time Taken to Sign 0.7528989315032959
# Signature Size 13683 bytes
# Time Taken to Verify 0.02193927764892578
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.46153688430786133
# Time Taken to Sign 238.59824562072754
# Signature Size 12853 bytes
# Time Taken to Verify 0.1531693935394287
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C2 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.026928424835205078
# Time Taken to Sign 1.0841662883758545
# Signature Size 31214 bytes
# Time Taken to Verify 0.03494548797607422
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.717688798904419
# Time Taken to Sign 289.39307260513306
# Signature Size 25253 bytes
# Time Taken to Verify 0.11684632301330566
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.07239341735839844
# Time Taken to Sign 2.067417860031128
# Signature Size 44956 bytes
# Time Taken to Verify 0.03391122817993164
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.49854540824890137
# Time Taken to Sign 188.47698593139648
# Signature Size 5541 bytes
# Time Taken to Verify 0.0819234848022461
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.014957427978515625
# Time Taken to Sign 0.989905595779419
# Signature Size 12682 bytes
# Time Taken to Verify 0.019534826278686523
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.40206360816955566
# Time Taken to Sign 232.22229075431824
# Signature Size 12325 bytes
# Time Taken to Verify 0.1332838535308838
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C3 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.02440619468688965
# Time Taken to Sign 1.4094910621643066
# Signature Size 29707 bytes
# Time Taken to Verify 0.030404329299926758
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6616721153259277
# Time Taken to Sign 280.6435091495514
# Signature Size 24549 bytes
# Time Taken to Verify 0.11121273040771484
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06832742691040039
# Time Taken to Sign 2.0932729244232178
# Signature Size 43422 bytes
# Time Taken to Verify 0.03387737274169922
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.4330918788909912
# Time Taken to Sign 181.7552559375763
# Signature Size 5189 bytes
# Time Taken to Verify 0.07116866111755371
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.013278961181640625
# Time Taken to Sign 7.2455785274505615
# Signature Size 11679 bytes
# Time Taken to Verify 0.019411802291870117
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.368314266204834
# Time Taken to Sign 226.68283939361572
# Signature Size 11797 bytes
# Time Taken to Verify 0.12218403816223145
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C4 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.023449420928955078
# Time Taken to Sign 2.5987181663513184
# Signature Size 28196 bytes
# Time Taken to Verify 0.02888965606689453
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6290755271911621
# Time Taken to Sign 275.9786374568939
# Signature Size 23845 bytes
# Time Taken to Verify 0.10319805145263672
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06450057029724121
# Time Taken to Sign 2.6764605045318604
# Signature Size 41891 bytes
# Time Taken to Verify 0.03241610527038574
# Is signature correct ?  True
# --------------------------------------------------

# %%
df = pd.DataFrame(val_arr)

# %%
df.to_csv("result-SKEIN.csv", encoding='utf-8', index=False)

# %%
df.head(len(val_arr))
# Out:
#     SK Size  PK Size  Key Gen Time  Sign Size   Sign Time  Verify Time  \
# 0        64       32      0.140723       9248    3.083435     0.011537
# 1        64       32      0.016991      15824    0.588815     0.019916
# 2        96       48      0.106327      19800   10.019717     0.017950
# 3        96       48      0.024932      34440    0.871546     0.030915
# 4       128       64      0.271111      34848    9.742208     0.021911
# 5       128       64      0.070324      48352    1.827955     0.033441
# 6        64       32      0.641112       6245  196.974474     0.106332
# 7        64       32      0.018614      14688    0.732114     0.023936
# 8        96       48      0.473555      13381  239.001666     0.156470
# 9        96       48      0.028428      32725    1.114995     0.035871
# 10      128       64      0.731211      25957  295.134192     0.123184
# 11      128       64      0.075308      46497    2.280282     0.035929
# 12       64       32      0.567775       5893  191.912430     0.100243
# 13       64       32      0.017534      13683    0.752899     0.021939
# 14       96       48      0.461537      12853  238.598246     0.153169
# 15       96       48      0.026928      31214    1.084166     0.034945
# 16      128       64      0.717689      25253  289.393073     0.116846
# 17      128       64      0.072393      44956    2.067418     0.033911
# 18       64       32      0.498545       5541  188.476986     0.081923
# 19       64       32      0.014957      12682    0.989906     0.019535
# 20       96       48      0.402064      12325  232.222291     0.133284
# 21       96       48      0.024406      29707    1.409491     0.030404
# 22      128       64      0.661672      24549  280.643509     0.111213
# 23      128       64      0.068327      43422    2.093273     0.033877
# 24       64       32      0.433092       5189  181.755256     0.071169
# 25       64       32      0.013279      11679    7.245579     0.019412
# 26       96       48      0.368314      11797  226.682839     0.122184
# 27       96       48      0.023449      28196    2.598718     0.028890
# 28      128       64      0.629076      23845  275.978637     0.103198
# 29      128       64      0.064501      41891    2.676461     0.032416
#
#                Name
# 0     SPHINCS+ 128S
# 1     SPHINCS+ 128F
# 2     SPHINCS+ 192S
# 3     SPHINCS+ 192F
# 4     SPHINCS+ 256S
# 5     SPHINCS+ 256F
# 6   SPHINCS+C1 128S
# 7   SPHINCS+C1 128F
# 8   SPHINCS+C1 192S
# 9   SPHINCS+C1 192F
# 10  SPHINCS+C1 256S
# 11  SPHINCS+C1 256F
# 12  SPHINCS+C2 128S
# 13  SPHINCS+C2 128F
# 14  SPHINCS+C2 192S
# 15  SPHINCS+C2 192F
# 16  SPHINCS+C2 256S
# 17  SPHINCS+C2 256F
# 18  SPHINCS+C3 128S
# 19  SPHINCS+C3 128F
# 20  SPHINCS+C3 192S
# 21  SPHINCS+C3 192F
# 22  SPHINCS+C3 256S
# 23  SPHINCS+C3 256F
# 24  SPHINCS+C4 128S
# 25  SPHINCS+C4 128F
# 26  SPHINCS+C4 192S
# 27  SPHINCS+C4 192F
# 28  SPHINCS+C4 256S
# 29  SPHINCS+C4 256F

# %%
df = df.round(3)

# %%
def plot_bar_multi_columns(data, x_col, y_cols, y_label, colormap='viridis'):
    """
    Create a bar plot for multiple columns in a Pandas DataFrame with a gap between groups.

    Parameters:
    - data: The DataFrame containing the data to be plotted.
    - x_col: The name of the column to be used as the X-axis.
    - y_cols: A list of column names to be used as Y-axes.
    """
    # Extract X and Y data from the DataFrame
    x_data = data[x_col]
    y_data = data[y_cols]

    # Number of bars (Y-axes)
    num_y_axes = len(y_cols)

    # Set up the figure and axis with a larger figsize
    fig, ax = plt.subplots(figsize=(16, 10))

    # Width of each group of bars
    group_width = 1
    bar_width = (group_width / num_y_axes)-0.2

    # Define color options for bars
    colors = ['g', 'y', 'm', 'b', 'r', 'c', 'k']

    # Loop through each Y-axis and create a bar for each
    for i in range(num_y_axes):
        x_positions = [x + i * bar_width for x in range(len(x_data))]
        y_values = y_data[y_cols[i]]
        color = colors[i % len(colors)]  # Cycle through colors

        ax.bar(x_positions, y_values, width=bar_width, label=y_cols[i], color=color)

        # Add annotations to the bars
        for x, y in zip(x_positions, y_values):
            ax.text((x + bar_width / 2)-0.4, y, str(y), ha='center', va='bottom')

    # Set the X-axis labels and legend
    ax.set_xticks([(x + (group_width / 2))-0.5 for x in range(len(x_data))])
    ax.set_xticklabels(x_data, rotation=90, va='top')
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_label)
    ax.legend()

# %%
plot_bar_multi_columns(df, 'Name', ["Key Gen Time"], "Keys Generation Time (in seconds)", 'hsv')

# %%
plot_bar_multi_columns(df, 'Name', ["SK Size","PK Size"], "Key Size (in bytes)")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Time"], "Signature Generation Time (in seconds)")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Size"], "Signature Size (in bytes)")

# %%
plot_bar_multi_columns(df, 'Name', ["Verify Time"], "Verification Time (in seconds)")

# %%
df2 = df.sort_values(by=['Sign Size'])

# %%
plot_bar_multi_columns(df2, 'Name', ["Key Gen Time"], "Keys Generation Time (in seconds)", 'hsv')

# %%
plot_bar_multi_columns(df2, 'Name', ["SK Size","PK Size"], "Key Size (in bytes)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Sign Time"], "Signature Generation Time (in seconds)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Sign Size"], "Signature Size (in bytes)")

# %%
plot_bar_multi_columns(df2, 'Name', ["Verify Time"], "Verification Time (in seconds)")
