# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Declaring Global Parameters

# %%
a = 15 # FORS Tree Height
# k = 10 # FORS Tree Number
val_arr = []

# %%
parameters = {
    "128S" : {
        "n":16,
        "h":66,
        "d":11,
        "k":9,
        "w":128,
        "a":13
    },
    "128F" : {
        "n":16,
        "h":63,
        "d":21,
        "k":19,
        "w":16,
        "a":9
    },
    "192S" : {
        "n":24,
        "h":63,
        "d":11,
        "k":13,
        "w":128,
        "a":15
    },
    "192F" : {
        "n":24,
        "h":63,
        "d":21,
        "k":30,
        "w":16,
        "a":9
    },
    "256S" : {
        "n":32,
        "h":66,
        "d":11,
        "k":19,
        "w":64,
        "a":14
    },
    "256F" : {
        "n":32,
        "h":64,
        "d":16,
        "k":34,
        "w":16,
        "a":10
    },
}

m = b"No one knows the reason for all this, but it is probably quantum. - Pyramids, Terry Pratchett (1989)"

# %% [markdown]
# # SPHINCS+

# %%
from package.sphincs import Sphincs
from package.sphincsc2 import SphincsC

# %%
def SphincsUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = Sphincs()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except:
        
        print(name + " Failed")
    
    print("-"*50, "\n")

    return di

# %%
def SphincsCUtil(n, h, d, w, a, k, name, cf=1):
    sphincsc = SphincsC()
    di= {}
    sphincsc.set_n(n)
    sphincsc.set_h(h)
    sphincsc.set_d(d)
    sphincsc.set_w(w)
    sphincsc.set_a(a)
    sphincsc.set_k(k)
    sphincsc.set_cf(cf)
    
    start = time.time()
    sk, pk = sphincsc.generate_key_pair()
    end = time.time()
    key_gen_time = end-start
    print("Secret Key Size: ", len(sk))
    print("Public Key Size: ", len(pk))
    print("Time Taken to Generate Keys", key_gen_time)
    di["SK Size"] = len(sk) 
    di["PK Size"] = len(pk)
    di["Key Gen Time"]  = key_gen_time

    try:
    
        start = time.time()
        signature = sphincsc.sign(m, sk)
        end = time.time()
        sign_time = end-start
        print("Time Taken to Sign", sign_time)
        print("Signature Size", len(signature), "bytes")

        start = time.time()
        verify_true = sphincsc.verify(m, signature, pk)
        end = time.time()
        verify_time = end-start
        print("Time Taken to Verify", verify_time)
        print("Is signature correct ? ", verify_true)

        di["Sign Size"] = len(signature)
        di["Sign Time"] = sign_time
        di["Verify Time"] = verify_time
        
    except Exception as e:
        
        print(name + " Failed")
        print(e)
    
    print("-"*50, "\n")

    return di

# %% [markdown]
# ## SPHINCS+128S

# %%
models = ["SPHINCS+", "SPHINCS+C1", "SPHINCS+C2", "SPHINCS+C3", "SPHINCS+C4"]
parameter_names = list(parameters.keys())

for cf, name in enumerate(models):
    if cf == 0:
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsUtil(**param, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
            print("-"*50, "\n")
    else:
        if name.endswith("F"):
            continue
        for param_set in parameter_names:
            print(name + ' ' + param_set)
            param = parameters[param_set]
            d = SphincsCUtil(**param, cf=cf, name = name + ' ' + param_set)
            d["Name"] = name + ' ' + param_set
            val_arr.append(d)
# Out:
# SPHINCS+ 128S
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.23834609985351562
# Time Taken to Sign 4.561851501464844
# Signature Size 9248 bytes
# Time Taken to Verify 0.018978357315063477
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 128F
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.02853107452392578
# Time Taken to Sign 0.8897998332977295
# Signature Size 15824 bytes
# Time Taken to Verify 0.03638601303100586
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192S
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.16080236434936523
# Time Taken to Sign 12.825195789337158
# Signature Size 19800 bytes
# Time Taken to Verify 0.02644181251525879
# Is signature correct ?  False
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 192F
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.0388951301574707
# Time Taken to Sign 1.2482030391693115
# Signature Size 34440 bytes
# Time Taken to Verify 0.05034494400024414
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256S
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.43476271629333496
# Time Taken to Sign 13.453407287597656
# Signature Size 34848 bytes
# Time Taken to Verify 0.033422231674194336
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+ 256F
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.10169339179992676
# Time Taken to Sign 2.6871538162231445
# Signature Size 48352 bytes
# Time Taken to Verify 0.06180596351623535
# Is signature correct ?  True
# --------------------------------------------------
#
# --------------------------------------------------
#
# SPHINCS+C1 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5856139659881592
# Time Taken to Sign 209.48943257331848
# Signature Size 6245 bytes
# Time Taken to Verify 0.04957389831542969
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.01930713653564453
# Time Taken to Sign 0.7130208015441895
# Signature Size 14689 bytes
# Time Taken to Verify 0.023056983947753906
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.4537632465362549
# Time Taken to Sign 275.83998465538025
# Signature Size 13381 bytes
# Time Taken to Verify 0.07936334609985352
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C1 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.038871049880981445
# Time Taken to Sign 1.2316036224365234
# Signature Size 32724 bytes
# Time Taken to Verify 0.034874916076660156
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.7732248306274414
# Time Taken to Sign 343.61064434051514
# Signature Size 25957 bytes
# Time Taken to Verify 0.06054496765136719
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C1 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 1
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.07467818260192871
# Time Taken to Sign 2.2165591716766357
# Signature Size 46491 bytes
# Time Taken to Verify 0.03252601623535156
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5403072834014893
# Time Taken to Sign 227.47949957847595
# Signature Size 5893 bytes
# Time Taken to Verify 0.07306742668151855
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.020503520965576172
# Time Taken to Sign 0.8722896575927734
# Signature Size 13683 bytes
# Time Taken to Verify 0.023595094680786133
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.44440221786499023
# Time Taken to Sign 276.65714621543884
# Signature Size 12853 bytes
# Time Taken to Verify 0.07094979286193848
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C2 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.029788970947265625
# Time Taken to Sign 1.284217119216919
# Signature Size 31215 bytes
# Time Taken to Verify 0.036197662353515625
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.7178685665130615
# Time Taken to Sign 363.95546770095825
# Signature Size 25253 bytes
# Time Taken to Verify 0.07047390937805176
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C2 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 2
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.08590221405029297
# Time Taken to Sign 2.4027137756347656
# Signature Size 44956 bytes
# Time Taken to Verify 0.03986334800720215
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.5174810886383057
# Time Taken to Sign 245.2480185031891
# Signature Size 5541 bytes
# Time Taken to Verify 0.03892374038696289
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.013994455337524414
# Time Taken to Sign 1.0090274810791016
# Signature Size 12679 bytes
# Time Taken to Verify 0.017554044723510742
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.37606191635131836
# Time Taken to Sign 260.7969057559967
# Signature Size 12325 bytes
# Time Taken to Verify 0.050803184509277344
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C3 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.024435997009277344
# Time Taken to Sign 1.3612427711486816
# Signature Size 29707 bytes
# Time Taken to Verify 0.028889894485473633
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6059491634368896
# Time Taken to Sign 13.640274047851562
# Signature Size 24536 bytes
# Time Taken to Verify 0.04938101768493652
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C3 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 3
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06399679183959961
# Time Taken to Sign 2.23486590385437
# Signature Size 43421 bytes
# Time Taken to Verify 0.03684401512145996
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128S
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 13
# Recalculation called
# Value of  changed
# 9
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.4014554023742676
# Time Taken to Sign 204.27952814102173
# Signature Size 5189 bytes
# Time Taken to Verify 0.030883312225341797
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 128F
# Value of n changed
# 16
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  64
# Public Key Size:  32
# Time Taken to Generate Keys 0.012996912002563477
# Time Taken to Sign 13.316866874694824
# Signature Size 11679 bytes
# Time Taken to Verify 0.016953229904174805
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 192S
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 128
# Recalculation called
# Value of a changed
# 15
# Recalculation called
# Value of  changed
# 13
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.34624528884887695
# Time Taken to Sign 257.1330614089966
# Signature Size 11797 bytes
# Time Taken to Verify 0.05310201644897461
# Is signature correct ?  False
# --------------------------------------------------
#
# SPHINCS+C4 192F
# Value of n changed
# 24
# Recalculation called
# Value of h changed
# 63
# Recalculation called
# Value of d changed
# 21
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 9
# Recalculation called
# Value of  changed
# 30
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  96
# Public Key Size:  48
# Time Taken to Generate Keys 0.022516727447509766
# Time Taken to Sign 3.036555528640747
# Signature Size 28197 bytes
# Time Taken to Verify 0.02861499786376953
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256S
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 66
# Recalculation called
# Value of d changed
# 11
# Recalculation called
# Value of w changed
# 64
# Recalculation called
# Value of a changed
# 14
# Recalculation called
# Value of  changed
# 19
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.6359524726867676
# Time Taken to Sign 336.3785729408264
# Signature Size 23845 bytes
# Time Taken to Verify 0.05246853828430176
# Is signature correct ?  True
# --------------------------------------------------
#
# SPHINCS+C4 256F
# Value of n changed
# 32
# Recalculation called
# Value of h changed
# 64
# Recalculation called
# Value of d changed
# 16
# Recalculation called
# Value of w changed
# 16
# Recalculation called
# Value of a changed
# 10
# Recalculation called
# Value of  changed
# 34
# Recalculation called
# Value of cf changed
# 4
# Recalculation called
# Secret Key Size:  128
# Public Key Size:  64
# Time Taken to Generate Keys 0.06428050994873047
# Time Taken to Sign 2.998670816421509
# Signature Size 41890 bytes
# Time Taken to Verify 0.03241300582885742
# Is signature correct ?  True
# --------------------------------------------------

# %%
df = pd.DataFrame(val_arr)

# %%
df.to_csv("result2.csv", encoding='utf-8', index=False)

# %%
df.head(len(val_arr))
# Out:
#     SK Size  PK Size  Key Gen Time  Sign Size   Sign Time  Verify Time  \
# 0        64       32      0.238346       9248    4.561852     0.018978
# 1        64       32      0.028531      15824    0.889800     0.036386
# 2        96       48      0.160802      19800   12.825196     0.026442
# 3        96       48      0.038895      34440    1.248203     0.050345
# 4       128       64      0.434763      34848   13.453407     0.033422
# 5       128       64      0.101693      48352    2.687154     0.061806
# 6        64       32      0.585614       6245  209.489433     0.049574
# 7        64       32      0.019307      14689    0.713021     0.023057
# 8        96       48      0.453763      13381  275.839985     0.079363
# 9        96       48      0.038871      32724    1.231604     0.034875
# 10      128       64      0.773225      25957  343.610644     0.060545
# 11      128       64      0.074678      46491    2.216559     0.032526
# 12       64       32      0.540307       5893  227.479500     0.073067
# 13       64       32      0.020504      13683    0.872290     0.023595
# 14       96       48      0.444402      12853  276.657146     0.070950
# 15       96       48      0.029789      31215    1.284217     0.036198
# 16      128       64      0.717869      25253  363.955468     0.070474
# 17      128       64      0.085902      44956    2.402714     0.039863
# 18       64       32      0.517481       5541  245.248019     0.038924
# 19       64       32      0.013994      12679    1.009027     0.017554
# 20       96       48      0.376062      12325  260.796906     0.050803
# 21       96       48      0.024436      29707    1.361243     0.028890
# 22      128       64      0.605949      24536   13.640274     0.049381
# 23      128       64      0.063997      43421    2.234866     0.036844
# 24       64       32      0.401455       5189  204.279528     0.030883
# 25       64       32      0.012997      11679   13.316867     0.016953
# 26       96       48      0.346245      11797  257.133061     0.053102
# 27       96       48      0.022517      28197    3.036556     0.028615
# 28      128       64      0.635952      23845  336.378573     0.052469
# 29      128       64      0.064281      41890    2.998671     0.032413
#
#                Name
# 0     SPHINCS+ 128S
# 1     SPHINCS+ 128F
# 2     SPHINCS+ 192S
# 3     SPHINCS+ 192F
# 4     SPHINCS+ 256S
# 5     SPHINCS+ 256F
# 6   SPHINCS+C1 128S
# 7   SPHINCS+C1 128F
# 8   SPHINCS+C1 192S
# 9   SPHINCS+C1 192F
# 10  SPHINCS+C1 256S
# 11  SPHINCS+C1 256F
# 12  SPHINCS+C2 128S
# 13  SPHINCS+C2 128F
# 14  SPHINCS+C2 192S
# 15  SPHINCS+C2 192F
# 16  SPHINCS+C2 256S
# 17  SPHINCS+C2 256F
# 18  SPHINCS+C3 128S
# 19  SPHINCS+C3 128F
# 20  SPHINCS+C3 192S
# 21  SPHINCS+C3 192F
# 22  SPHINCS+C3 256S
# 23  SPHINCS+C3 256F
# 24  SPHINCS+C4 128S
# 25  SPHINCS+C4 128F
# 26  SPHINCS+C4 192S
# 27  SPHINCS+C4 192F
# 28  SPHINCS+C4 256S
# 29  SPHINCS+C4 256F

# %%
df = df.round(3)

# %%
def plot_bar_multi_columns(data, x_col, y_cols, y_label, colormap='viridis'):
    """
    Create a bar plot for multiple columns in a Pandas DataFrame with a gap between groups.

    Parameters:
    - data: The DataFrame containing the data to be plotted.
    - x_col: The name of the column to be used as the X-axis.
    - y_cols: A list of column names to be used as Y-axes.
    """
    # Extract X and Y data from the DataFrame
    x_data = data[x_col]
    y_data = data[y_cols]

    # Number of bars (Y-axes)
    num_y_axes = len(y_cols)

    # Set up the figure and axis with a larger figsize
    fig, ax = plt.subplots(figsize=(16, 10))

    # Width of each group of bars
    group_width = 1
    bar_width = (group_width / num_y_axes)-0.2

    # Define color options for bars
    colors = ['g', 'y', 'm', 'b', 'r', 'c', 'k']

    # Loop through each Y-axis and create a bar for each
    for i in range(num_y_axes):
        x_positions = [x + i * bar_width for x in range(len(x_data))]
        y_values = y_data[y_cols[i]]
        color = colors[i % len(colors)]  # Cycle through colors

        ax.bar(x_positions, y_values, width=bar_width, label=y_cols[i], color=color)

        # Add annotations to the bars
        for x, y in zip(x_positions, y_values):
            ax.text((x + bar_width / 2)-0.4, y, str(y), ha='center', va='bottom')

    # Set the X-axis labels and legend
    ax.set_xticks([(x + (group_width / 2))-0.5 for x in range(len(x_data))])
    ax.set_xticklabels(x_data, rotation=90, va='top')
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_label)
    ax.legend()

# %%
plot_bar_multi_columns(df, 'Name', ["Key Gen Time"], "Keys Generation Time", 'hsv')

# %%
plot_bar_multi_columns(df, 'Name', ["SK Size","PK Size"], "Key Size")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Time"], "Signature Generation Time")

# %%
plot_bar_multi_columns(df, 'Name', ["Sign Size"], "Signature Size")

# %%
plot_bar_multi_columns(df, 'Name', ["Verify Time"], "Verification Time")

# %%
df
# Out:
#     SK Size  PK Size  Key Gen Time  Sign Size  Sign Time  Verify Time  \
# 0        64       32         0.238       9248      4.562        0.019
# 1        64       32         0.029      15824      0.890        0.036
# 2        96       48         0.161      19800     12.825        0.026
# 3        96       48         0.039      34440      1.248        0.050
# 4       128       64         0.435      34848     13.453        0.033
# 5       128       64         0.102      48352      2.687        0.062
# 6        64       32         0.586       6245    209.489        0.050
# 7        64       32         0.019      14689      0.713        0.023
# 8        96       48         0.454      13381    275.840        0.079
# 9        96       48         0.039      32724      1.232        0.035
# 10      128       64         0.773      25957    343.611        0.061
# 11      128       64         0.075      46491      2.217        0.033
# 12       64       32         0.540       5893    227.479        0.073
# 13       64       32         0.021      13683      0.872        0.024
# 14       96       48         0.444      12853    276.657        0.071
# 15       96       48         0.030      31215      1.284        0.036
# 16      128       64         0.718      25253    363.955        0.070
# 17      128       64         0.086      44956      2.403        0.040
# 18       64       32         0.517       5541    245.248        0.039
# 19       64       32         0.014      12679      1.009        0.018
# 20       96       48         0.376      12325    260.797        0.051
# 21       96       48         0.024      29707      1.361        0.029
# 22      128       64         0.606      24536     13.640        0.049
# 23      128       64         0.064      43421      2.235        0.037
# 24       64       32         0.401       5189    204.280        0.031
# 25       64       32         0.013      11679     13.317        0.017
# 26       96       48         0.346      11797    257.133        0.053
# 27       96       48         0.023      28197      3.037        0.029
# 28      128       64         0.636      23845    336.379        0.052
# 29      128       64         0.064      41890      2.999        0.032
#
#                Name
# 0     SPHINCS+ 128S
# 1     SPHINCS+ 128F
# 2     SPHINCS+ 192S
# 3     SPHINCS+ 192F
# 4     SPHINCS+ 256S
# 5     SPHINCS+ 256F
# 6   SPHINCS+C1 128S
# 7   SPHINCS+C1 128F
# 8   SPHINCS+C1 192S
# 9   SPHINCS+C1 192F
# 10  SPHINCS+C1 256S
# 11  SPHINCS+C1 256F
# 12  SPHINCS+C2 128S
# 13  SPHINCS+C2 128F
# 14  SPHINCS+C2 192S
# 15  SPHINCS+C2 192F
# 16  SPHINCS+C2 256S
# 17  SPHINCS+C2 256F
# 18  SPHINCS+C3 128S
# 19  SPHINCS+C3 128F
# 20  SPHINCS+C3 192S
# 21  SPHINCS+C3 192F
# 22  SPHINCS+C3 256S
# 23  SPHINCS+C3 256F
# 24  SPHINCS+C4 128S
# 25  SPHINCS+C4 128F
# 26  SPHINCS+C4 192S
# 27  SPHINCS+C4 192F
# 28  SPHINCS+C4 256S
# 29  SPHINCS+C4 256F
